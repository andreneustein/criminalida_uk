# %%
## Definindo caminho para as bases
path = r"C:\Users\andre\Desktop\FACULDADE\2022.2 ÚLTIMO\BIgData\Projeto\Crimes in UK"
print(path)
# Out:
# C:\Users\andre\Desktop\FACULDADE\2022.2 ÚLTIMO\BIgData\Projeto\Crimes in UK

# %%
## Observando a versão do Dask
# !pip show dask
# Out:
# Name: dask
# Version: 2022.2.1
# Summary: Parallel PyData with Task Scheduling
# Home-page: https://github.com/dask/dask/
# Author:
# Author-email:
# License: BSD
# Location: c:\users\andre\anaconda3\lib\site-packages
# Requires: cloudpickle, fsspec, packaging, partd, pyyaml, toolz
# Required-by: datashader, distributed, intake

# %%
# Para utilizar recursos do sistema
import os
import sys

# Bibliotecas DASK
import dask
from dask.distributed import Client
import dask.dataframe as dd # similar ao pandas
import dask.multiprocessing

# Para plot
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
print('Executável:')
print(sys.executable)

print('\nVersão do Python:')
print(sys.version)
# Out:
# Executável:
# C:\Users\andre\anaconda3\python.exe
#
# Versão do Python:
# 3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]

# %%
## Definindo os clusters
client = Client(n_workers=4, threads_per_worker=1, memory_limit='1GB')

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:57035' processes=4 threads=4, memory=3.73 GiB>

# %%
## Trazendo 3 bases para observação inicial, as bases são referentes à mesma localização mas com
## informações diferentes
metro_outcomes = dd.read_csv(f"{path}\\metropolitan-outcomes.csv")
metro_sas = dd.read_csv(f"{path}\\metropolitan-stop-and-search.csv")
metro_street = dd.read_csv(f"{path}\\metropolitan-street.csv")

# %%
metro_outcomes.tail()
# Out:
#                                                  Crime ID    Month  \
# 293602  77e2ea6be9266ddbf76ddfd5ff09b6a06a1e190f931388...  2022-02
# 293603  d127aa5fb0d3851edd7bad23a0ba09b20db0697cf107fd...  2022-02
# 293604  17f40817c172f2caab47952127f75cdbebe5645f50c079...  2022-02
# 293605  a0e9343c352bc36c35dcedf8810f4fa49b08aa9fb6485c...  2022-02
# 293606  36058772908c3c515645d39aace0c7377b27205d08b83d...  2022-02
#
#                         Reported by                 Falls within  Longitude  \
# 293602  Metropolitan Police Service  Metropolitan Police Service  -0.059500
# 293603  Metropolitan Police Service  Metropolitan Police Service  -0.076231
# 293604  Metropolitan Police Service  Metropolitan Police Service  -0.087202
# 293605  Metropolitan Police Service  Metropolitan Police Service  -0.127942
# 293606  Metropolitan Police Service  Metropolitan Police Service  -0.056667
#
#          Latitude                      Location  LSOA code      LSOA name  \
# 293602  51.667785  On or near WORCESTERS AVENUE  E01001410   Enfield 005C
# 293603  51.651748       On or near Parking Area  E01001512   Enfield 015D
# 293604  51.608162    On or near MAYFAIR GARDENS  E01002091  Haringey 006A
# 293605  51.630661        On or near HIGH STREET  E01001519   Enfield 020D
# 293606  51.633279         On or near WATER LANE  E01001479   Enfield 023A
#
#                                          Outcome type
# 293602  Investigation complete; no suspect identified
# 293603  Investigation complete; no suspect identified
# 293604  Investigation complete; no suspect identified
# 293605  Investigation complete; no suspect identified
# 293606  Investigation complete; no suspect identified

# %%
metro_sas.tail()
# Out:
#                              Type                       Date  \
# 406474              Person search  2022-02-28T23:47:00+00:00
# 406475              Person search  2022-02-28T23:49:00+00:00
# 406476              Person search  2022-02-28T23:49:00+00:00
# 406477  Person and Vehicle search  2022-02-28T23:54:00+00:00
# 406478  Person and Vehicle search  2022-02-28T23:55:00+00:00
#
#         Part of a policing operation  Policing operation   Latitude  \
# 406474                         False                 NaN  51.533295
# 406475                         False                 NaN  51.491231
# 406476                         False                 NaN  51.533295
# 406477                         False                 NaN  51.432683
# 406478                         False                 NaN  51.432683
#
#         Longitude  Gender Age range  \
# 406474   0.030731    Male       NaN
# 406475  -0.141971    Male     18-24
# 406476   0.030731    Male       NaN
# 406477  -0.117358  Female     25-34
# 406478  -0.117358    Male       NaN
#
#                                    Self-defined ethnicity  \
# 406474    Black/African/Caribbean/Black British - African
# 406475   Asian/Asian British - Any other Asian background
# 406476    Black/African/Caribbean/Black British - African
# 406477                    Other ethnic group - Not stated
# 406478  Black/African/Caribbean/Black British - Any ot...
#
#        Officer-defined ethnicity                            Legislation  \
# 406474                     Black  Misuse of Drugs Act 1971 (section 23)
# 406475                     Asian  Misuse of Drugs Act 1971 (section 23)
# 406476                     Black  Misuse of Drugs Act 1971 (section 23)
# 406477                     Black  Misuse of Drugs Act 1971 (section 23)
# 406478                     Black  Misuse of Drugs Act 1971 (section 23)
#
#         Object of search                       Outcome  \
# 406474  Controlled drugs  A no further action disposal
# 406475  Controlled drugs          Community resolution
# 406476  Controlled drugs  A no further action disposal
# 406477  Controlled drugs  A no further action disposal
# 406478  Controlled drugs  A no further action disposal
#
#         Outcome linked to object of search  \
# 406474                                 NaN
# 406475                                 NaN
# 406476                                 NaN
# 406477                                 NaN
# 406478                                 NaN
#
#         Removal of more than just outer clothing
# 406474                                       NaN
# 406475                                       NaN
# 406476                                       NaN
# 406477                                       NaN
# 406478                                       NaN

# %%
metro_street.tail()
# Out:
#                                                  Crime ID    Month  \
# 300495  7489141f0b1e66061ba502fea713ef041b5f0b98b0ed51...  2022-02
# 300496  1a0081408e088d0ae813855e565a909d2bf814d0b88d3e...  2022-02
# 300497  5f32be16c45d6746f1299fe486e5727808b72eee47179c...  2022-02
# 300498  9715eb632a7260b5103f8a7d8e1ae61832d3bcf83368dd...  2022-02
# 300499  70012e405cd9ef652d2a3398a8055f6560bc4675eb1330...  2022-02
#
#                         Reported by                 Falls within  Longitude  \
# 300495  Metropolitan Police Service  Metropolitan Police Service        NaN
# 300496  Metropolitan Police Service  Metropolitan Police Service        NaN
# 300497  Metropolitan Police Service  Metropolitan Police Service        NaN
# 300498  Metropolitan Police Service  Metropolitan Police Service        NaN
# 300499  Metropolitan Police Service  Metropolitan Police Service        NaN
#
#         Latitude     Location LSOA code LSOA name   Crime type  \
# 300495       NaN  No Location       NaN       NaN  Other crime
# 300496       NaN  No Location       NaN       NaN  Other crime
# 300497       NaN  No Location       NaN       NaN  Other crime
# 300498       NaN  No Location       NaN       NaN  Other crime
# 300499       NaN  No Location       NaN       NaN  Other crime
#
#                                 Last outcome category  Context
# 300495                            Under investigation      NaN
# 300496                            Under investigation      NaN
# 300497  Investigation complete; no suspect identified      NaN
# 300498                            Under investigation      NaN
# 300499                            Under investigation      NaN

# %%
metro_outcomes.dtypes
# Out:
# Crime ID         object
# Month            object
# Reported by      object
# Falls within     object
# Longitude       float64
# Latitude        float64
# Location         object
# LSOA code        object
# LSOA name        object
# Outcome type     object
# dtype: object

# %%
metro_sas.dtypes
# Out:
# Type                                         object
# Date                                         object
# Part of a policing operation                   bool
# Policing operation                          float64
# Latitude                                    float64
# Longitude                                   float64
# Gender                                       object
# Age range                                    object
# Self-defined ethnicity                       object
# Officer-defined ethnicity                    object
# Legislation                                  object
# Object of search                             object
# Outcome                                      object
# Outcome linked to object of search          float64
# Removal of more than just outer clothing    float64
# dtype: object

# %%
metro_street.dtypes
# Out:
# Crime ID                  object
# Month                     object
# Reported by               object
# Falls within              object
# Longitude                float64
# Latitude                 float64
# Location                  object
# LSOA code                 object
# LSOA name                 object
# Crime type                object
# Last outcome category     object
# Context                  float64
# dtype: object

# %%
freq_resul = metro_outcomes['Outcome type'].value_counts().compute()
freq_resul
# Out:
# Investigation complete; no suspect identified    1495781
# Suspect charged                                   135554
# Local resolution                                   88293
# Offender given penalty notice                      20496
# Offender given a caution                           20444
# Offender given a drugs possession warning           1587
# Offender fined                                       705
# Offender sent to prison                              684
# Offender given community sentence                    662
# Court case unable to proceed                         303
# Offender given conditional discharge                 275
# Suspect charged as part of another case              252
# Defendant found not guilty                           238
# Offender given suspended prison sentence             220
# Defendant sent to Crown Court                        108
# Offender deprived of property                         81
# Formal action is not in the public interest           66
# Offender otherwise dealt with                         63
# Offender ordered to pay compensation                  50
# Unable to prosecute suspect                           19
# Offender given absolute discharge                      5
# Name: Outcome type, dtype: int64

# %%
## Trazendo outras 3 bases para observar se as colunas batem com as colunas das bases dos mesmos 
## assuntos importadas anteriormente
west_york_outcomes = dd.read_csv(f"{path}\\west-yorkshire-outcomes.csv")
west_york_sas = dd.read_csv(f"{path}\\west-yorkshire-stop-and-search.csv")
west_york_street = dd.read_csv(f"{path}\\west-yorkshire-street.csv")

# %%
west_york_outcomes.tail()
# Out:
#                                                  Crime ID    Month  \
# 398543  67de21aa6b1bf813a7fae676d64e63f59a5992e26768a6...  2022-02
# 398544  64eeac05e5d92c545a6ce7686efaa7fd2e1e849b0479d3...  2022-02
# 398545  bb7221911ad347d95aed8ea1fda63ce0bc62e3ec2fe574...  2022-02
# 398546  9cac13b4430f464b30d1e765eebf6495d183edd5ab908d...  2022-02
# 398547  6a49f34a79160b56c2344b5b57f04b43ca93b4f0fd486c...  2022-02
#
#                   Reported by           Falls within  Longitude   Latitude  \
# 398543  West Yorkshire Police  West Yorkshire Police  -1.676957  53.684940
# 398544  West Yorkshire Police  West Yorkshire Police  -1.541457  53.797982
# 398545  West Yorkshire Police  West Yorkshire Police  -1.818117  53.558350
# 398546  West Yorkshire Police  West Yorkshire Police  -1.780100  53.576892
# 398547  West Yorkshire Police  West Yorkshire Police  -1.780100  53.576892
#
#                           Location  LSOA code      LSOA name      Outcome type
# 398543  On or near NORTHORPE COURT  E01011142  Kirklees 020B   Suspect charged
# 398544    On or near Shopping Area  E01033010     Leeds 111B  Local resolution
# 398545   On or near MOSS EDGE VIEW  E01011182  Kirklees 058B  Local resolution
# 398546     On or near BRAMBLE BANK  E01011187  Kirklees 059F  Local resolution
# 398547     On or near BRAMBLE BANK  E01011187  Kirklees 059F  Local resolution

# %%
west_york_sas.tail()
# Out:
#                             Type                       Date  \
# 51556  Person and Vehicle search  2022-02-28T22:45:00+00:00
# 51557  Person and Vehicle search  2022-02-28T23:00:00+00:00
# 51558              Person search  2022-02-28T23:10:00+00:00
# 51559              Person search  2022-02-28T23:30:00+00:00
# 51560  Person and Vehicle search  2022-02-28T23:42:00+00:00
#
#        Part of a policing operation  Policing operation   Latitude  Longitude  \
# 51556                         False                 NaN        NaN        NaN
# 51557                         False                 NaN  53.746067  -1.635988
# 51558                         False                 NaN  53.700790  -1.416581
# 51559                         False                 NaN  53.718465  -1.891694
# 51560                         False                 NaN  53.718465  -1.891694
#
#       Gender Age range                             Self-defined ethnicity  \
# 51556   Male     25-34                    Asian/Asian British - Pakistani
# 51557   Male   over 34  White - English/Welsh/Scottish/Northern Irish/...
# 51558   Male     10-17  White - English/Welsh/Scottish/Northern Irish/...
# 51559   Male     25-34                    Asian/Asian British - Pakistani
# 51560   Male     25-34                    Asian/Asian British - Pakistani
#
#       Officer-defined ethnicity                            Legislation  \
# 51556                     Asian  Misuse of Drugs Act 1971 (section 23)
# 51557                     White  Misuse of Drugs Act 1971 (section 23)
# 51558                     White  Misuse of Drugs Act 1971 (section 23)
# 51559                     Asian  Misuse of Drugs Act 1971 (section 23)
# 51560                     Asian  Misuse of Drugs Act 1971 (section 23)
#
#        Object of search                       Outcome  \
# 51556  Controlled drugs                        Arrest
# 51557  Controlled drugs          Community resolution
# 51558  Controlled drugs  A no further action disposal
# 51559  Controlled drugs  A no further action disposal
# 51560  Controlled drugs                        Arrest
#
#        Outcome linked to object of search  \
# 51556                               False
# 51557                               False
# 51558                               False
# 51559                               False
# 51560                                True
#
#        Removal of more than just outer clothing
# 51556                                     False
# 51557                                     False
# 51558                                      True
# 51559                                     False
# 51560                                     False

# %%
west_york_street.tail()
# Out:
#                                                  Crime ID    Month  \
# 321398  28d3b366feb2f0d5eef79b1bc4485e78be8e6135b5be98...  2022-02
# 321399  af5e77971b1ea6fa74341f4b58207e5c8e063b7a00fc3e...  2022-02
# 321400  da5ee98200d4c3ab3592ae87157ea658a60fdabeed1428...  2022-02
# 321401  848013e744fa11b0d7e8eaa051d5423e6e93e805d93674...  2022-02
# 321402  1b4d6c84d668cf10a6c873d689d4324008446855a4b3aa...  2022-02
#
#                   Reported by           Falls within  Longitude  Latitude  \
# 321398  West Yorkshire Police  West Yorkshire Police        NaN       NaN
# 321399  West Yorkshire Police  West Yorkshire Police        NaN       NaN
# 321400  West Yorkshire Police  West Yorkshire Police        NaN       NaN
# 321401  West Yorkshire Police  West Yorkshire Police        NaN       NaN
# 321402  West Yorkshire Police  West Yorkshire Police        NaN       NaN
#
#            Location LSOA code LSOA name   Crime type  \
# 321398  No Location       NaN       NaN  Other crime
# 321399  No Location       NaN       NaN  Other crime
# 321400  No Location       NaN       NaN  Other crime
# 321401  No Location       NaN       NaN  Other crime
# 321402  No Location       NaN       NaN  Other crime
#
#                                 Last outcome category  Context
# 321398                            Under investigation      NaN
# 321399                            Under investigation      NaN
# 321400                            Under investigation      NaN
# 321401  Investigation complete; no suspect identified      NaN
# 321402                            Under investigation      NaN

# %%
## Lista com os arquivos na pasta de importação
files = os.listdir(path)
files
# Out:
# ['avon-and-somerset-outcomes.csv',
#  'avon-and-somerset-stop-and-search.csv',
#  'avon-and-somerset-street.csv',
#  'bedfordshire-outcomes.csv',
#  'bedfordshire-stop-and-search.csv',
#  'bedfordshire-street.csv',
#  'btp-stop-and-search.csv',
#  'btp-street.csv',
#  'cambridgeshire-outcomes.csv',
#  'cambridgeshire-stop-and-search.csv',
#  'cambridgeshire-street.csv',
#  'cheshire-outcomes.csv',
#  'cheshire-stop-and-search.csv',
#  'cheshire-street.csv',
#  'city-of-london-outcomes.csv',
#  'city-of-london-stop-and-search.csv',
#  'city-of-london-street.csv',
#  'cleveland-outcomes.csv',
#  'cleveland-stop-and-search.csv',
#  'cleveland-street.csv',
#  'cumbria-outcomes.csv',
#  'cumbria-stop-and-search.csv',
#  'cumbria-street.csv',
#  'derbyshire-outcomes.csv',
#  'derbyshire-stop-and-search.csv',
#  'derbyshire-street.csv',
#  'devon-and-cornwall-outcomes.csv',
#  'devon-and-cornwall-stop-and-search.csv',
#  'devon-and-cornwall-street.csv',
#  'dorset-outcomes.csv',
#  'dorset-stop-and-search.csv',
#  'dorset-street.csv',
#  'durham-outcomes.csv',
#  'durham-stop-and-search.csv',
#  'durham-street.csv',
#  'dyfed-powys-outcomes.csv',
#  'dyfed-powys-stop-and-search.csv',
#  'dyfed-powys-street.csv',
#  'essex-outcomes.csv',
#  'essex-stop-and-search.csv',
#  'essex-street.csv',
#  'gloucestershire-outcomes.csv',
#  'gloucestershire-stop-and-search.csv',
#  'gloucestershire-street.csv',
#  'greater-manchester-outcomes.csv',
#  'greater-manchester-stop-and-search.csv',
#  'greater-manchester-street.csv',
#  'gwent-outcomes.csv',
#  'gwent-stop-and-search.csv',
#  'gwent-street.csv',
#  'hampshire-outcomes.csv',
#  'hampshire-stop-and-search.csv',
#  'hampshire-street.csv',
#  'hertfordshire-outcomes.csv',
#  'hertfordshire-stop-and-search.csv',
#  'hertfordshire-street.csv',
#  'humberside-outcomes.csv',
#  'humberside-stop-and-search.csv',
#  'humberside-street.csv',
#  'kent-outcomes.csv',
#  'kent-stop-and-search.csv',
#  'kent-street.csv',
#  'lancashire-outcomes.csv',
#  'lancashire-stop-and-search.csv',
#  'lancashire-street.csv',
#  'leicestershire-outcomes.csv',
#  'leicestershire-stop-and-search.csv',
#  'lincolnshire-street.csv',
#  'merseyside-outcomes.csv',
#  'merseyside-stop-and-search.csv',
#  'merseyside-street.csv',
#  'metropolitan-outcomes.csv',
#  'metropolitan-stop-and-search.csv',
#  'metropolitan-street.csv',
#  'norfolk-outcomes.csv',
#  'norfolk-stop-and-search.csv',
#  'norfolk-street.csv',
#  'north-wales-outcomes.csv',
#  'north-wales-stop-and-search.csv',
#  'north-wales-street.csv',
#  'north-yorkshire-outcomes.csv',
#  'north-yorkshire-stop-and-search.csv',
#  'north-yorkshire-street.csv',
#  'northamptonshire-outcomes.csv',
#  'northamptonshire-stop-and-search.csv',
#  'northamptonshire-street.csv',
#  'northern-ireland-street.csv',
#  'northumbria-outcomes.csv',
#  'northumbria-stop-and-search.csv',
#  'northumbria-street.csv',
#  'nottinghamshire-outcomes.csv',
#  'nottinghamshire-stop-and-search.csv',
#  'nottinghamshire-street.csv',
#  'south-wales-outcomes.csv',
#  'south-wales-stop-and-search.csv',
#  'south-wales-street.csv',
#  'south-yorkshire-outcomes.csv',
#  'south-yorkshire-stop-and-search.csv',
#  'south-yorkshire-street.csv',
#  'staffordshire-outcomes.csv',
#  'staffordshire-stop-and-search.csv',
#  'staffordshire-street.csv',
#  'suffolk-outcomes.csv',
#  'suffolk-stop-and-search.csv',
#  'suffolk-street.csv',
#  'surrey-outcomes.csv',
#  'surrey-stop-and-search.csv',
#  'surrey-street.csv',
#  'sussex-outcomes.csv',
#  'sussex-stop-and-search.csv',
#  'sussex-street.csv',
#  'thames-valley-outcomes.csv',
#  'thames-valley-stop-and-search.csv',
#  'thames-valley-street.csv',
#  'warwickshire-outcomes.csv',
#  'warwickshire-stop-and-search.csv',
#  'warwickshire-street.csv',
#  'west-mercia-outcomes.csv',
#  'west-mercia-stop-and-search.csv',
#  'west-mercia-street.csv',
#  'west-midlands-outcomes.csv',
#  'west-midlands-stop-and-search.csv',
#  'west-midlands-street.csv',
#  'west-yorkshire-outcomes.csv',
#  'west-yorkshire-stop-and-search.csv',
#  'west-yorkshire-street.csv',
#  'wiltshire-outcomes.csv',
#  'wiltshire-stop-and-search.csv',
#  'wiltshire-street.csv']

# %%
path_outcomes = r"C:\Users\andre\Desktop\FACULDADE\2022.2 ÚLTIMO\BIgData\Projeto\Crimes in UK\Outcomes"
path_street = r"C:\Users\andre\Desktop\FACULDADE\2022.2 ÚLTIMO\BIgData\Projeto\Crimes in UK\Street"
path_stse = r"C:\Users\andre\Desktop\FACULDADE\2022.2 ÚLTIMO\BIgData\Projeto\Crimes in UK\StopAndSearch"

# %%
files_out = os.listdir(path_outcomes)
files_out
# Out:
# ['avon-and-somerset-outcomes.csv',
#  'bedfordshire-outcomes.csv',
#  'cambridgeshire-outcomes.csv',
#  'cheshire-outcomes.csv',
#  'city-of-london-outcomes.csv',
#  'cleveland-outcomes.csv',
#  'cumbria-outcomes.csv',
#  'derbyshire-outcomes.csv',
#  'devon-and-cornwall-outcomes.csv',
#  'dorset-outcomes.csv',
#  'durham-outcomes.csv',
#  'dyfed-powys-outcomes.csv',
#  'essex-outcomes.csv',
#  'gloucestershire-outcomes.csv',
#  'greater-manchester-outcomes.csv',
#  'gwent-outcomes.csv',
#  'hampshire-outcomes.csv',
#  'hertfordshire-outcomes.csv',
#  'humberside-outcomes.csv',
#  'kent-outcomes.csv',
#  'lancashire-outcomes.csv',
#  'leicestershire-outcomes.csv',
#  'merseyside-outcomes.csv',
#  'metropolitan-outcomes.csv',
#  'norfolk-outcomes.csv',
#  'north-wales-outcomes.csv',
#  'north-yorkshire-outcomes.csv',
#  'northamptonshire-outcomes.csv',
#  'northumbria-outcomes.csv',
#  'nottinghamshire-outcomes.csv',
#  'south-wales-outcomes.csv',
#  'south-yorkshire-outcomes.csv',
#  'staffordshire-outcomes.csv',
#  'suffolk-outcomes.csv',
#  'surrey-outcomes.csv',
#  'sussex-outcomes.csv',
#  'thames-valley-outcomes.csv',
#  'warwickshire-outcomes.csv',
#  'west-mercia-outcomes.csv',
#  'west-midlands-outcomes.csv',
#  'west-yorkshire-outcomes.csv',
#  'wiltshire-outcomes.csv']

# %%
avon_and_somerset_outcomes = []
bedfordshire_outcomes = []
cambridgeshire_outcomes = []
cheshire_outcomes = []
city_of_london_outcomes = []
cleveland_outcomes = []
cumbria_outcomes = []
derbyshire_outcomes = []
devon_and_cornwall_outcomes = []
dorset_outcomes = []
durham_outcomes = []
dyfed_powys_outcomes = []
essex_outcomes = []
gloucestershire_outcomes = []
greater_manchester_outcomes = []
gwent_outcomes = []
hampshire_outcomes = []
hertfordshire_outcomes = []
humberside_outcomes = []
kent_outcomes = []
lancashire_outcomes = []
leicestershire_outcomes = []
merseyside_outcomes = []
metropolitan_outcomes = []
norfolk_outcomes = []
north_wales_outcomes = []
north_yorkshire_outcomes = []
northamptonshire_outcomes = []
northumbria_outcomes = []
nottinghamshire_outcomes = []
south_wales_outcomes = []
south_yorkshire_outcomes = []
staffordshire_outcomes = []
suffolk_outcomes = []
surrey_outcomes = []
sussex_outcomes = []
thames_valley_outcomes = []
warwickshire_outcomes = []
west_mercia_outcomes = []
west_midlands_outcomes = []
west_yorkshire_outcomes = []
wiltshire_outcomes = []

# %%
nome_dfs = [avon_and_somerset_outcomes,
            bedfordshire_outcomes,
            cambridgeshire_outcomes,
            cheshire_outcomes,
            city_of_london_outcomes,
            cleveland_outcomes,
            cumbria_outcomes,
            derbyshire_outcomes,
            devon_and_cornwall_outcomes,
            dorset_outcomes,
            durham_outcomes,
            dyfed_powys_outcomes,
            essex_outcomes,
            gloucestershire_outcomes,
            greater_manchester_outcomes,
            gwent_outcomes,
            hampshire_outcomes,
            hertfordshire_outcomes,
            humberside_outcomes,
            kent_outcomes,
            lancashire_outcomes,
            leicestershire_outcomes,
            merseyside_outcomes,
            metropolitan_outcomes,
            norfolk_outcomes,
            north_wales_outcomes,
            north_yorkshire_outcomes,
            northamptonshire_outcomes,
            northumbria_outcomes,
            nottinghamshire_outcomes,
            south_wales_outcomes,
            south_yorkshire_outcomes,
            staffordshire_outcomes,
            suffolk_outcomes,
            surrey_outcomes,
            sussex_outcomes,
            thames_valley_outcomes,
            warwickshire_outcomes,
            west_mercia_outcomes,
            west_midlands_outcomes,
            west_yorkshire_outcomes,
            wiltshire_outcomes]

# %%
nome_cidades = ['avon and somerset',
            'bedfordshire',
            'cambridgeshire',
            'cheshire',
            'city of london',
            'cleveland',
            'cumbria',
            'derbyshire',
            'devon and cornwall',
            'dorset',
            'durham',
            'dyfed powys',
            'essex',
            'gloucestershire',
            'greater manchester',
            'gwent',
            'hampshire',
            'hertfordshire',
            'humberside',
            'kent',
            'lancashire',
            'leicestershire',
            'merseyside',
            'metropolitan',
            'norfolk',
            'north wales',
            'north yorkshire',
            'northamptonshire',
            'northumbria',
            'nottinghamshire',
            'south wales',
            'south yorkshire',
            'staffordshire',
            'suffolk',
            'surrey',
            'sussex',
            'thames valley',
            'warwickshire',
            'west mercia',
            'west midlands',
            'west yorkshire',
            'wiltshire']

# %%
# %%time 
## Medindo o tempo para rodar a célula (em média 20min)
## loop com as listas criadas, para cada arquivo na pasta será rodado o for, que importará o
## arquivo e colocará o nome da cidade em uma nova coluna, posteriormente os arquivos serão
## empilhados para facilitar o trabalho da dupla
for file,df,city in zip(files_out,nome_dfs,nome_cidades):
    ## Leitura do arquivo excel
    df = dd.read_csv(os.path.join(path_outcomes,file))
    ## criando coluna 'cidade" e incluindo a cidade correspondente
    df['cidade'] = city
# Out:
# CPU times: total: 78.1 ms
# Wall time: 534 ms
